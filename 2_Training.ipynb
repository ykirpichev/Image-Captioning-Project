# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:** I decided to implement architecture described by [this paper](https://arxiv.org/pdf/1411.4555.pdf)
# Basically, it is LSTM model combined with a CNN image embedder and word embeddings.
# #### Encoder
# ![Encoder](images/encoder.png)
# #### Decoder
# ![Decoder](images/decoder.png)
# The next step which I would like to try is check [CNN+RNN model with attention](https://arxiv.org/pdf/1502.03044.pdf), but it was not tried yet.
#
# Also, I consulted [this paper](https://arxiv.org/pdf/1411.4555.pdf) in order to choose hyperparameters, namely:
# ```
# We trained all sets of weights using stochastic gradient descent with fixed learning rate and no momentum.
# All weights were randomly initialized except for the CNN weights, which we left unchanged because changing them
# had a negative impact. We used 512 dimensions for the embeddings and the size of the LSTM memory.
# Descriptions were preprocessed with basic tokenization, keeping all words that appeared at least 5 times in the training set.
# ```
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:** I used provided transform without any changes. I think it is reasonable choice, because:
# 1. Input size corresponds to required input size by user CNN in encoder.
# 2. It augments dataset a little bit, increasing size of dataset and reduce probability of overfitting.
# 3. It uses color normalization which is considered the best for used CNN architecture.
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:** I selected `list(decoder.parameters()) + list(encoder.embed.parameters())`. I followed approach recommended by [Show and Tell: A Neural Image Caption Generator](https://arxiv.org/pdf/1411.4555.pdf).
#
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:** According to [the paper](https://arxiv.org/pdf/1411.4555.pdf) they used stochastic gradient
# descent with fixed learning rate and no momentum, but, I, persanally, like Adam optimizer, so, I used Adam optimizer.

# %%
# Watch for any changes in model.py, and re-load it automatically.
% load_ext autoreload
% autoreload 2

import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 64          # batch size
vocab_threshold = 5        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 512           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 50          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = list(decoder.parameters()) + list(encoder.embed.parameters())

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=0.56s)
# creating index...
#   0%|          | 903/414113 [00:00<00:45, 9025.25it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [00:39<00:00, 10430.61it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
try:
    response = requests.request("GET", 
                                "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                                headers={"Metadata-Flavor":"Google"})
except:
    pass
    
for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        try:
            if time.time() - old_time > 60:
                old_time = time.time()
                requests.request("POST", 
                                 "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                                 headers={'Authorization': "STAR " + response.text})
        except Exception as ex:
            pass
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
#        print('\r' + stats, end="")
#        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/3], Step [50/6471], Loss: 4.3913, Perplexity: 80.7439
# Epoch [1/3], Step [100/6471], Loss: 3.7665, Perplexity: 43.2267
# Epoch [1/3], Step [150/6471], Loss: 3.6779, Perplexity: 39.5640
# Epoch [1/3], Step [200/6471], Loss: 3.3297, Perplexity: 27.9293
# Epoch [1/3], Step [250/6471], Loss: 3.2937, Perplexity: 26.9427
# Epoch [1/3], Step [300/6471], Loss: 3.5280, Perplexity: 34.0547
# Epoch [1/3], Step [350/6471], Loss: 3.3716, Perplexity: 29.1265
# Epoch [1/3], Step [400/6471], Loss: 2.9417, Perplexity: 18.9479
# Epoch [1/3], Step [450/6471], Loss: 3.1809, Perplexity: 24.0695
# Epoch [1/3], Step [500/6471], Loss: 3.0061, Perplexity: 20.2076
# Epoch [1/3], Step [550/6471], Loss: 2.9178, Perplexity: 18.5012
# Epoch [1/3], Step [600/6471], Loss: 2.7792, Perplexity: 16.1068
# Epoch [1/3], Step [650/6471], Loss: 2.7171, Perplexity: 15.1367
# Epoch [1/3], Step [700/6471], Loss: 2.6582, Perplexity: 14.2706
# Epoch [1/3], Step [750/6471], Loss: 2.4459, Perplexity: 11.5412
# Epoch [1/3], Step [800/6471], Loss: 2.6315, Perplexity: 13.8948
# Epoch [1/3], Step [850/6471], Loss: 2.5697, Perplexity: 13.0625
# Epoch [1/3], Step [900/6471], Loss: 2.3096, Perplexity: 10.0707
# Epoch [1/3], Step [950/6471], Loss: 2.7402, Perplexity: 15.4899
# Epoch [1/3], Step [1000/6471], Loss: 2.6763, Perplexity: 14.5310
# Epoch [1/3], Step [1050/6471], Loss: 2.3955, Perplexity: 10.9741
# Epoch [1/3], Step [1100/6471], Loss: 2.9332, Perplexity: 18.7880
# Epoch [1/3], Step [1150/6471], Loss: 3.2854, Perplexity: 26.7195
# Epoch [1/3], Step [1200/6471], Loss: 2.4480, Perplexity: 11.5655
# Epoch [1/3], Step [1250/6471], Loss: 2.6213, Perplexity: 13.7543
# Epoch [1/3], Step [1300/6471], Loss: 2.5902, Perplexity: 13.3321
# Epoch [1/3], Step [1350/6471], Loss: 2.5986, Perplexity: 13.4448
# Epoch [1/3], Step [1400/6471], Loss: 3.0422, Perplexity: 20.9520
# Epoch [1/3], Step [1450/6471], Loss: 2.5847, Perplexity: 13.2589
# Epoch [1/3], Step [1500/6471], Loss: 2.5047, Perplexity: 12.2401
# Epoch [1/3], Step [1550/6471], Loss: 2.2570, Perplexity: 9.5545
# Epoch [1/3], Step [1600/6471], Loss: 2.2306, Perplexity: 9.3057
# Epoch [1/3], Step [1650/6471], Loss: 2.5328, Perplexity: 12.5891
# Epoch [1/3], Step [1700/6471], Loss: 2.4235, Perplexity: 11.2848
# Epoch [1/3], Step [1750/6471], Loss: 3.2942, Perplexity: 26.9553
# Epoch [1/3], Step [1800/6471], Loss: 2.2599, Perplexity: 9.5819
# Epoch [1/3], Step [1850/6471], Loss: 2.2877, Perplexity: 9.8521
# Epoch [1/3], Step [1900/6471], Loss: 2.5626, Perplexity: 12.9697
# Epoch [1/3], Step [1950/6471], Loss: 2.1869, Perplexity: 8.9079
# Epoch [1/3], Step [2000/6471], Loss: 2.1799, Perplexity: 8.8455
# Epoch [1/3], Step [2050/6471], Loss: 2.4094, Perplexity: 11.1276
# Epoch [1/3], Step [2100/6471], Loss: 2.1629, Perplexity: 8.6967
# Epoch [1/3], Step [2150/6471], Loss: 2.3004, Perplexity: 9.9779
# Epoch [1/3], Step [2200/6471], Loss: 2.4001, Perplexity: 11.0241
# Epoch [1/3], Step [2250/6471], Loss: 2.2286, Perplexity: 9.2865
# Epoch [1/3], Step [2300/6471], Loss: 2.2140, Perplexity: 9.1526
# Epoch [1/3], Step [2350/6471], Loss: 2.2404, Perplexity: 9.3971
# Epoch [1/3], Step [2400/6471], Loss: 2.4756, Perplexity: 11.8885
# Epoch [1/3], Step [2450/6471], Loss: 2.1557, Perplexity: 8.6343
# Epoch [1/3], Step [2500/6471], Loss: 2.4019, Perplexity: 11.0443
# Epoch [1/3], Step [2550/6471], Loss: 2.2657, Perplexity: 9.6379
# Epoch [1/3], Step [2600/6471], Loss: 2.1979, Perplexity: 9.0060
# Epoch [1/3], Step [2650/6471], Loss: 2.3341, Perplexity: 10.3201
# Epoch [1/3], Step [2800/6471], Loss: 2.2102, Perplexity: 9.1179
# Epoch [1/3], Step [2850/6471], Loss: 2.2781, Perplexity: 9.7584
# Epoch [1/3], Step [2900/6471], Loss: 2.2515, Perplexity: 9.5023
# Epoch [1/3], Step [2950/6471], Loss: 1.9702, Perplexity: 7.1724
# Epoch [1/3], Step [3000/6471], Loss: 2.6331, Perplexity: 13.9173
# Epoch [1/3], Step [3050/6471], Loss: 2.8364, Perplexity: 17.0547
# Epoch [1/3], Step [3100/6471], Loss: 2.7646, Perplexity: 15.8729
# Epoch [1/3], Step [3150/6471], Loss: 2.3287, Perplexity: 10.2648
# Epoch [1/3], Step [3200/6471], Loss: 2.0306, Perplexity: 7.6184
# Epoch [1/3], Step [3250/6471], Loss: 2.4155, Perplexity: 11.1954
# Epoch [1/3], Step [3300/6471], Loss: 2.1882, Perplexity: 8.9191
# Epoch [1/3], Step [3350/6471], Loss: 2.3434, Perplexity: 10.4171
# Epoch [1/3], Step [3400/6471], Loss: 2.4557, Perplexity: 11.6541
# Epoch [1/3], Step [3450/6471], Loss: 2.5198, Perplexity: 12.4266
# Epoch [1/3], Step [3500/6471], Loss: 2.4052, Perplexity: 11.0803
# Epoch [1/3], Step [3550/6471], Loss: 2.4313, Perplexity: 11.3732
# Epoch [1/3], Step [3600/6471], Loss: 2.2581, Perplexity: 9.5649
# Epoch [1/3], Step [3650/6471], Loss: 2.2003, Perplexity: 9.0276
# Epoch [1/3], Step [3700/6471], Loss: 2.3040, Perplexity: 10.0142
# Epoch [1/3], Step [3750/6471], Loss: 2.3092, Perplexity: 10.0666
# Epoch [1/3], Step [3800/6471], Loss: 2.4138, Perplexity: 11.1762
# Epoch [1/3], Step [3850/6471], Loss: 2.1859, Perplexity: 8.8986
# Epoch [1/3], Step [3900/6471], Loss: 2.2985, Perplexity: 9.9594
# Epoch [1/3], Step [3950/6471], Loss: 2.3533, Perplexity: 10.5204
# Epoch [1/3], Step [4000/6471], Loss: 2.1835, Perplexity: 8.8773
# Epoch [1/3], Step [4050/6471], Loss: 2.3795, Perplexity: 10.7991
# Epoch [1/3], Step [4100/6471], Loss: 2.0809, Perplexity: 8.0114
# Epoch [1/3], Step [4150/6471], Loss: 2.0011, Perplexity: 7.3975
# Epoch [1/3], Step [4200/6471], Loss: 2.3068, Perplexity: 10.0422
# Epoch [1/3], Step [4250/6471], Loss: 2.0902, Perplexity: 8.0868
# Epoch [1/3], Step [4300/6471], Loss: 2.3497, Perplexity: 10.4824
# Epoch [1/3], Step [4350/6471], Loss: 2.6895, Perplexity: 14.7237
# Epoch [1/3], Step [4400/6471], Loss: 2.2188, Perplexity: 9.1958
# Epoch [1/3], Step [4450/6471], Loss: 2.3830, Perplexity: 10.8378
# Epoch [1/3], Step [4500/6471], Loss: 1.9686, Perplexity: 7.1608
# Epoch [1/3], Step [4550/6471], Loss: 2.2535, Perplexity: 9.5209
# Epoch [1/3], Step [4600/6471], Loss: 2.1422, Perplexity: 8.5182
# Epoch [1/3], Step [4650/6471], Loss: 2.1754, Perplexity: 8.8060
# Epoch [1/3], Step [4700/6471], Loss: 1.9117, Perplexity: 6.7645
# Epoch [1/3], Step [4750/6471], Loss: 2.1324, Perplexity: 8.4351
# Epoch [1/3], Step [4800/6471], Loss: 2.1144, Perplexity: 8.2848
# Epoch [1/3], Step [4850/6471], Loss: 2.1912, Perplexity: 8.9461
# Epoch [1/3], Step [4900/6471], Loss: 2.0895, Perplexity: 8.0809
# Epoch [1/3], Step [4950/6471], Loss: 2.5325, Perplexity: 12.5848
# Epoch [1/3], Step [5000/6471], Loss: 2.0978, Perplexity: 8.1484
# Epoch [1/3], Step [5050/6471], Loss: 1.9895, Perplexity: 7.3116
# Epoch [1/3], Step [5100/6471], Loss: 2.1507, Perplexity: 8.5905
# Epoch [1/3], Step [5150/6471], Loss: 2.2118, Perplexity: 9.1321
# Epoch [1/3], Step [5200/6471], Loss: 1.9913, Perplexity: 7.3249
# Epoch [1/3], Step [5250/6471], Loss: 2.4957, Perplexity: 12.1301
# Epoch [1/3], Step [5300/6471], Loss: 2.0283, Perplexity: 7.6015
# Epoch [1/3], Step [5350/6471], Loss: 2.1916, Perplexity: 8.9497
# Epoch [1/3], Step [5400/6471], Loss: 2.0414, Perplexity: 7.7012
# Epoch [1/3], Step [5450/6471], Loss: 2.2667, Perplexity: 9.6476
# Epoch [1/3], Step [5500/6471], Loss: 2.0336, Perplexity: 7.6414
# Epoch [1/3], Step [5550/6471], Loss: 2.1389, Perplexity: 8.4903
# Epoch [1/3], Step [5600/6471], Loss: 2.0511, Perplexity: 7.7766
# Epoch [1/3], Step [5650/6471], Loss: 3.1117, Perplexity: 22.4590
# Epoch [1/3], Step [5700/6471], Loss: 1.9523, Perplexity: 7.0450
# Epoch [1/3], Step [5750/6471], Loss: 2.6510, Perplexity: 14.1682
# Epoch [1/3], Step [5800/6471], Loss: 2.8827, Perplexity: 17.8624
# Epoch [1/3], Step [5850/6471], Loss: 2.2160, Perplexity: 9.1710
# Epoch [1/3], Step [5900/6471], Loss: 2.1216, Perplexity: 8.3441
# Epoch [1/3], Step [5950/6471], Loss: 1.9948, Perplexity: 7.3507
# Epoch [1/3], Step [6000/6471], Loss: 2.0545, Perplexity: 7.8032
# Epoch [1/3], Step [6050/6471], Loss: 2.1972, Perplexity: 8.9997
# Epoch [1/3], Step [6100/6471], Loss: 1.9618, Perplexity: 7.1123
# Epoch [1/3], Step [6150/6471], Loss: 2.0576, Perplexity: 7.8275
# Epoch [1/3], Step [6200/6471], Loss: 2.1100, Perplexity: 8.2480
# Epoch [1/3], Step [6250/6471], Loss: 2.7160, Perplexity: 15.1191
# Epoch [1/3], Step [6300/6471], Loss: 1.9628, Perplexity: 7.1192
# Epoch [1/3], Step [6350/6471], Loss: 2.0780, Perplexity: 7.9889
# Epoch [1/3], Step [6400/6471], Loss: 2.0005, Perplexity: 7.3927
# Epoch [1/3], Step [6450/6471], Loss: 2.0319, Perplexity: 7.6289
# Epoch [2/3], Step [50/6471], Loss: 2.6068, Perplexity: 13.5553
# Epoch [2/3], Step [100/6471], Loss: 2.1477, Perplexity: 8.5649
# Epoch [2/3], Step [150/6471], Loss: 2.0782, Perplexity: 7.9904
# Epoch [2/3], Step [200/6471], Loss: 2.1275, Perplexity: 8.3939
# Epoch [2/3], Step [250/6471], Loss: 2.0825, Perplexity: 8.0246
# Epoch [2/3], Step [300/6471], Loss: 2.0147, Perplexity: 7.4985
# Epoch [2/3], Step [350/6471], Loss: 2.1003, Perplexity: 8.1689
# Epoch [2/3], Step [400/6471], Loss: 1.9218, Perplexity: 6.8332
# Epoch [2/3], Step [450/6471], Loss: 1.9559, Perplexity: 7.0702
# Epoch [2/3], Step [500/6471], Loss: 1.9214, Perplexity: 6.8302
# Epoch [2/3], Step [550/6471], Loss: 1.9701, Perplexity: 7.1716
# Epoch [2/3], Step [600/6471], Loss: 1.9269, Perplexity: 6.8682
# Epoch [2/3], Step [650/6471], Loss: 2.1253, Perplexity: 8.3755
# Epoch [2/3], Step [700/6471], Loss: 2.0073, Perplexity: 7.4431
# Epoch [2/3], Step [750/6471], Loss: 1.9392, Perplexity: 6.9531
# Epoch [2/3], Step [800/6471], Loss: 2.0191, Perplexity: 7.5315
# Epoch [2/3], Step [850/6471], Loss: 1.9047, Perplexity: 6.7176
# Epoch [2/3], Step [900/6471], Loss: 1.9119, Perplexity: 6.7663
# Epoch [2/3], Step [950/6471], Loss: 1.9791, Perplexity: 7.2360
# Epoch [2/3], Step [1000/6471], Loss: 2.1093, Perplexity: 8.2421
# Epoch [2/3], Step [1050/6471], Loss: 1.9582, Perplexity: 7.0869
# Epoch [2/3], Step [1100/6471], Loss: 2.0854, Perplexity: 8.0477
# Epoch [2/3], Step [1150/6471], Loss: 1.9370, Perplexity: 6.9378
# Epoch [2/3], Step [1200/6471], Loss: 2.1121, Perplexity: 8.2659
# Epoch [2/3], Step [1250/6471], Loss: 1.8991, Perplexity: 6.6800
# Epoch [2/3], Step [1300/6471], Loss: 2.1897, Perplexity: 8.9322
# Epoch [2/3], Step [1350/6471], Loss: 1.9598, Perplexity: 7.0980
# Epoch [2/3], Step [1400/6471], Loss: 1.9731, Perplexity: 7.1926
# Epoch [2/3], Step [1450/6471], Loss: 2.0443, Perplexity: 7.7234
# Epoch [2/3], Step [1500/6471], Loss: 2.0247, Perplexity: 7.5737
# Epoch [2/3], Step [1550/6471], Loss: 1.9622, Perplexity: 7.1149
# Epoch [2/3], Step [1600/6471], Loss: 2.1504, Perplexity: 8.5883
# Epoch [2/3], Step [1650/6471], Loss: 1.9949, Perplexity: 7.3516
# Epoch [2/3], Step [1700/6471], Loss: 1.8814, Perplexity: 6.5624
# Epoch [2/3], Step [1750/6471], Loss: 1.8495, Perplexity: 6.3568
# Epoch [2/3], Step [1800/6471], Loss: 1.9786, Perplexity: 7.2324
# Epoch [2/3], Step [1850/6471], Loss: 2.2285, Perplexity: 9.2859
# Epoch [2/3], Step [1900/6471], Loss: 1.8291, Perplexity: 6.2281
# Epoch [2/3], Step [1950/6471], Loss: 2.1424, Perplexity: 8.5196
# Epoch [2/3], Step [2000/6471], Loss: 2.4220, Perplexity: 11.2682
# Epoch [2/3], Step [2050/6471], Loss: 2.3176, Perplexity: 10.1515
# Epoch [2/3], Step [2100/6471], Loss: 2.0832, Perplexity: 8.0302
# Epoch [2/3], Step [2150/6471], Loss: 2.0481, Perplexity: 7.7530
# Epoch [2/3], Step [2200/6471], Loss: 2.3765, Perplexity: 10.7670
# Epoch [2/3], Step [2250/6471], Loss: 1.9639, Perplexity: 7.1273
# Epoch [2/3], Step [2300/6471], Loss: 1.9225, Perplexity: 6.8382
# Epoch [2/3], Step [2350/6471], Loss: 2.0772, Perplexity: 7.9818
# Epoch [2/3], Step [2400/6471], Loss: 2.0779, Perplexity: 7.9873
# Epoch [2/3], Step [2450/6471], Loss: 2.2294, Perplexity: 9.2942
# Epoch [2/3], Step [2500/6471], Loss: 1.8642, Perplexity: 6.4509
# Epoch [2/3], Step [2550/6471], Loss: 1.7677, Perplexity: 5.8576
# Epoch [2/3], Step [2600/6471], Loss: 1.8900, Perplexity: 6.6192
# Epoch [2/3], Step [2650/6471], Loss: 2.5385, Perplexity: 12.6602
# Epoch [2/3], Step [2700/6471], Loss: 1.9603, Perplexity: 7.1015
# Epoch [2/3], Step [2750/6471], Loss: 2.3410, Perplexity: 10.3920
# Epoch [2/3], Step [2800/6471], Loss: 1.8625, Perplexity: 6.4399
# Epoch [2/3], Step [2850/6471], Loss: 1.8286, Perplexity: 6.2249
# Epoch [2/3], Step [2900/6471], Loss: 2.0657, Perplexity: 7.8908
# Epoch [2/3], Step [2950/6471], Loss: 1.9228, Perplexity: 6.8399
# Epoch [2/3], Step [3000/6471], Loss: 1.8922, Perplexity: 6.6342
# Epoch [2/3], Step [3050/6471], Loss: 2.1698, Perplexity: 8.7565
# Epoch [2/3], Step [3100/6471], Loss: 2.0533, Perplexity: 7.7937
# Epoch [2/3], Step [3150/6471], Loss: 2.0850, Perplexity: 8.0450
# Epoch [2/3], Step [3200/6471], Loss: 1.9320, Perplexity: 6.9036
# Epoch [2/3], Step [3250/6471], Loss: 2.1329, Perplexity: 8.4391
# Epoch [2/3], Step [3300/6471], Loss: 1.9488, Perplexity: 7.0206
# Epoch [2/3], Step [3350/6471], Loss: 1.9007, Perplexity: 6.6906
# Epoch [2/3], Step [3400/6471], Loss: 1.8957, Perplexity: 6.6573
# Epoch [2/3], Step [3450/6471], Loss: 2.1233, Perplexity: 8.3583
# Epoch [2/3], Step [3500/6471], Loss: 1.8135, Perplexity: 6.1317
# Epoch [2/3], Step [3550/6471], Loss: 1.8486, Perplexity: 6.3509
# Epoch [2/3], Step [3600/6471], Loss: 1.7124, Perplexity: 5.5423
# Epoch [2/3], Step [3650/6471], Loss: 2.0939, Perplexity: 8.1167
# Epoch [2/3], Step [3700/6471], Loss: 1.8902, Perplexity: 6.6208
# Epoch [2/3], Step [3750/6471], Loss: 1.8666, Perplexity: 6.4665
# Epoch [2/3], Step [3800/6471], Loss: 2.3636, Perplexity: 10.6293
# Epoch [2/3], Step [3850/6471], Loss: 2.0342, Perplexity: 7.6465
# Epoch [2/3], Step [3900/6471], Loss: 1.9601, Perplexity: 7.0997
# Epoch [2/3], Step [3950/6471], Loss: 1.9288, Perplexity: 6.8809
# Epoch [2/3], Step [4000/6471], Loss: 2.2816, Perplexity: 9.7927
# Epoch [2/3], Step [4050/6471], Loss: 2.3831, Perplexity: 10.8385
# Epoch [2/3], Step [4100/6471], Loss: 2.0948, Perplexity: 8.1235
# Epoch [2/3], Step [4150/6471], Loss: 2.7624, Perplexity: 15.8376
# Epoch [2/3], Step [4200/6471], Loss: 1.9269, Perplexity: 6.8679
# Epoch [2/3], Step [4250/6471], Loss: 1.9880, Perplexity: 7.3011
# Epoch [2/3], Step [4300/6471], Loss: 1.7923, Perplexity: 6.0035
# Epoch [2/3], Step [4350/6471], Loss: 2.0818, Perplexity: 8.0192
# Epoch [2/3], Step [4400/6471], Loss: 1.8717, Perplexity: 6.4996
# Epoch [2/3], Step [4450/6471], Loss: 1.7736, Perplexity: 5.8921
# Epoch [2/3], Step [4500/6471], Loss: 2.2161, Perplexity: 9.1718
# Epoch [2/3], Step [4550/6471], Loss: 1.8687, Perplexity: 6.4796
# Epoch [2/3], Step [4600/6471], Loss: 2.1368, Perplexity: 8.4720
# Epoch [2/3], Step [4650/6471], Loss: 1.8912, Perplexity: 6.6275
# Epoch [2/3], Step [4700/6471], Loss: 1.8179, Perplexity: 6.1590
# Epoch [2/3], Step [4750/6471], Loss: 1.9525, Perplexity: 7.0466
# Epoch [2/3], Step [4800/6471], Loss: 2.0005, Perplexity: 7.3926
# Epoch [2/3], Step [4850/6471], Loss: 2.2023, Perplexity: 9.0454
# Epoch [2/3], Step [4900/6471], Loss: 2.0407, Perplexity: 7.6957
# Epoch [2/3], Step [4950/6471], Loss: 1.8775, Perplexity: 6.5372
# Epoch [2/3], Step [5000/6471], Loss: 2.3850, Perplexity: 10.8586
# Epoch [2/3], Step [5050/6471], Loss: 1.7891, Perplexity: 5.9842
# Epoch [2/3], Step [5100/6471], Loss: 2.3130, Perplexity: 10.1047
# Epoch [2/3], Step [5150/6471], Loss: 2.0887, Perplexity: 8.0742
# Epoch [2/3], Step [5200/6471], Loss: 1.7369, Perplexity: 5.6794
# Epoch [2/3], Step [5250/6471], Loss: 1.8640, Perplexity: 6.4492
# Epoch [2/3], Step [5300/6471], Loss: 1.8232, Perplexity: 6.1918
# Epoch [2/3], Step [5350/6471], Loss: 2.0475, Perplexity: 7.7487
# Epoch [2/3], Step [5400/6471], Loss: 1.8244, Perplexity: 6.1994
# Epoch [2/3], Step [5450/6471], Loss: 2.3321, Perplexity: 10.2999
# Epoch [2/3], Step [5500/6471], Loss: 2.0506, Perplexity: 7.7728
# Epoch [2/3], Step [5550/6471], Loss: 1.8583, Perplexity: 6.4131
# Epoch [2/3], Step [5600/6471], Loss: 1.8448, Perplexity: 6.3269
# Epoch [2/3], Step [5650/6471], Loss: 1.8934, Perplexity: 6.6422
# Epoch [2/3], Step [5700/6471], Loss: 1.8854, Perplexity: 6.5888
# Epoch [2/3], Step [5750/6471], Loss: 2.1260, Perplexity: 8.3812
# Epoch [2/3], Step [5800/6471], Loss: 1.7503, Perplexity: 5.7562
# Epoch [2/3], Step [5850/6471], Loss: 1.9953, Perplexity: 7.3547
# Epoch [2/3], Step [5900/6471], Loss: 1.9874, Perplexity: 7.2965
# Epoch [2/3], Step [5950/6471], Loss: 2.9058, Perplexity: 18.2790
# Epoch [2/3], Step [6000/6471], Loss: 1.8943, Perplexity: 6.6482
# Epoch [2/3], Step [6050/6471], Loss: 2.0186, Perplexity: 7.5277
# Epoch [2/3], Step [6100/6471], Loss: 2.3400, Perplexity: 10.3817
# Epoch [2/3], Step [6150/6471], Loss: 2.2827, Perplexity: 9.8028
# Epoch [2/3], Step [6200/6471], Loss: 1.7591, Perplexity: 5.8074
# Epoch [2/3], Step [6250/6471], Loss: 2.1690, Perplexity: 8.7493
# Epoch [2/3], Step [6300/6471], Loss: 1.7823, Perplexity: 5.9435
# Epoch [2/3], Step [6350/6471], Loss: 2.0309, Perplexity: 7.6207
# Epoch [2/3], Step [6400/6471], Loss: 1.9550, Perplexity: 7.0639
# Epoch [2/3], Step [6450/6471], Loss: 1.9183, Perplexity: 6.8095
# Epoch [3/3], Step [50/6471], Loss: 1.7089, Perplexity: 5.5230
# Epoch [3/3], Step [100/6471], Loss: 1.8612, Perplexity: 6.4313
# Epoch [3/3], Step [150/6471], Loss: 1.9139, Perplexity: 6.7795
# Epoch [3/3], Step [200/6471], Loss: 1.7921, Perplexity: 6.0022
# Epoch [3/3], Step [250/6471], Loss: 1.9130, Perplexity: 6.7731
# Epoch [3/3], Step [300/6471], Loss: 1.9592, Perplexity: 7.0936
# Epoch [3/3], Step [350/6471], Loss: 1.8159, Perplexity: 6.1467
# Epoch [3/3], Step [400/6471], Loss: 1.8750, Perplexity: 6.5209
# Epoch [3/3], Step [450/6471], Loss: 1.8837, Perplexity: 6.5775
# Epoch [3/3], Step [500/6471], Loss: 1.9951, Perplexity: 7.3530
# Epoch [3/3], Step [550/6471], Loss: 1.7713, Perplexity: 5.8784
# Epoch [3/3], Step [600/6471], Loss: 2.0354, Perplexity: 7.6556
# Epoch [3/3], Step [650/6471], Loss: 1.8966, Perplexity: 6.6635
# Epoch [3/3], Step [700/6471], Loss: 2.0979, Perplexity: 8.1487
# Epoch [3/3], Step [750/6471], Loss: 1.7045, Perplexity: 5.4986
# Epoch [3/3], Step [800/6471], Loss: 2.0833, Perplexity: 8.0311
# Epoch [3/3], Step [850/6471], Loss: 2.1439, Perplexity: 8.5325
# Epoch [3/3], Step [900/6471], Loss: 2.0769, Perplexity: 7.9797
# Epoch [3/3], Step [950/6471], Loss: 1.8707, Perplexity: 6.4926
# Epoch [3/3], Step [1000/6471], Loss: 1.8871, Perplexity: 6.6004
# Epoch [3/3], Step [1050/6471], Loss: 1.8347, Perplexity: 6.2632
# Epoch [3/3], Step [1100/6471], Loss: 1.8064, Perplexity: 6.0883
# Epoch [3/3], Step [1150/6471], Loss: 1.8065, Perplexity: 6.0889
# Epoch [3/3], Step [1200/6471], Loss: 1.9638, Perplexity: 7.1261
# Epoch [3/3], Step [1250/6471], Loss: 2.1149, Perplexity: 8.2887
# Epoch [3/3], Step [1300/6471], Loss: 2.2293, Perplexity: 9.2930
# Epoch [3/3], Step [1350/6471], Loss: 1.9487, Perplexity: 7.0196
# Epoch [3/3], Step [1400/6471], Loss: 2.4886, Perplexity: 12.0441
# Epoch [3/3], Step [1450/6471], Loss: 1.7468, Perplexity: 5.7360
# Epoch [3/3], Step [1500/6471], Loss: 1.9552, Perplexity: 7.0657
# Epoch [3/3], Step [1550/6471], Loss: 2.3360, Perplexity: 10.3395
# Epoch [3/3], Step [1600/6471], Loss: 1.8389, Perplexity: 6.2895
# Epoch [3/3], Step [1650/6471], Loss: 1.8407, Perplexity: 6.3009
# Epoch [3/3], Step [1700/6471], Loss: 1.9059, Perplexity: 6.7257
# Epoch [3/3], Step [1750/6471], Loss: 2.2097, Perplexity: 9.1127
# Epoch [3/3], Step [1800/6471], Loss: 1.9472, Perplexity: 7.0089
# Epoch [3/3], Step [1850/6471], Loss: 2.2861, Perplexity: 9.8369
# Epoch [3/3], Step [1900/6471], Loss: 1.7319, Perplexity: 5.6515
# Epoch [3/3], Step [1950/6471], Loss: 1.8440, Perplexity: 6.3218
# Epoch [3/3], Step [2000/6471], Loss: 1.9405, Perplexity: 6.9624
# Epoch [3/3], Step [2050/6471], Loss: 2.1209, Perplexity: 8.3389
# Epoch [3/3], Step [2100/6471], Loss: 1.7745, Perplexity: 5.8972
# Epoch [3/3], Step [2150/6471], Loss: 1.9027, Perplexity: 6.7043
# Epoch [3/3], Step [2200/6471], Loss: 2.3947, Perplexity: 10.9644
# Epoch [3/3], Step [2250/6471], Loss: 1.9341, Perplexity: 6.9179
# Epoch [3/3], Step [2300/6471], Loss: 2.2885, Perplexity: 9.8602
# Epoch [3/3], Step [2350/6471], Loss: 1.9853, Perplexity: 7.2814
# Epoch [3/3], Step [2400/6471], Loss: 1.9018, Perplexity: 6.6979
# Epoch [3/3], Step [2450/6471], Loss: 2.1123, Perplexity: 8.2669
# Epoch [3/3], Step [2500/6471], Loss: 1.6145, Perplexity: 5.0253
# Epoch [3/3], Step [2550/6471], Loss: 1.8873, Perplexity: 6.6017
# Epoch [3/3], Step [2600/6471], Loss: 2.0845, Perplexity: 8.0403
# Epoch [3/3], Step [2650/6471], Loss: 1.7612, Perplexity: 5.8194
# Epoch [3/3], Step [2700/6471], Loss: 2.5583, Perplexity: 12.9142
# Epoch [3/3], Step [2750/6471], Loss: 1.7443, Perplexity: 5.7216
# Epoch [3/3], Step [2800/6471], Loss: 1.7751, Perplexity: 5.9006
# Epoch [3/3], Step [2850/6471], Loss: 1.8459, Perplexity: 6.3336
# Epoch [3/3], Step [2900/6471], Loss: 1.9158, Perplexity: 6.7921
# Epoch [3/3], Step [2950/6471], Loss: 2.3102, Perplexity: 10.0765
# Epoch [3/3], Step [3000/6471], Loss: 2.5464, Perplexity: 12.7610
# Epoch [3/3], Step [3050/6471], Loss: 1.9693, Perplexity: 7.1658
# Epoch [3/3], Step [3100/6471], Loss: 1.6787, Perplexity: 5.3583
# Epoch [3/3], Step [3150/6471], Loss: 1.9564, Perplexity: 7.0736
# Epoch [3/3], Step [3200/6471], Loss: 1.8186, Perplexity: 6.1632
# Epoch [3/3], Step [3250/6471], Loss: 1.6656, Perplexity: 5.2888
# Epoch [3/3], Step [3300/6471], Loss: 1.8491, Perplexity: 6.3541
# Epoch [3/3], Step [3350/6471], Loss: 1.7950, Perplexity: 6.0197
# Epoch [3/3], Step [3400/6471], Loss: 1.9416, Perplexity: 6.9699
# Epoch [3/3], Step [3450/6471], Loss: 1.9587, Perplexity: 7.0905
# Epoch [3/3], Step [3500/6471], Loss: 1.8377, Perplexity: 6.2820
# Epoch [3/3], Step [3550/6471], Loss: 1.8800, Perplexity: 6.5532
# Epoch [3/3], Step [3600/6471], Loss: 1.9213, Perplexity: 6.8295
# Epoch [3/3], Step [3650/6471], Loss: 1.7010, Perplexity: 5.4794
# Epoch [3/3], Step [3700/6471], Loss: 2.0071, Perplexity: 7.4417
# Epoch [3/3], Step [3750/6471], Loss: 1.8444, Perplexity: 6.3241
# Epoch [3/3], Step [3800/6471], Loss: 1.8705, Perplexity: 6.4915
# Epoch [3/3], Step [3850/6471], Loss: 1.8795, Perplexity: 6.5502
# Epoch [3/3], Step [3900/6471], Loss: 1.8518, Perplexity: 6.3715
# Epoch [3/3], Step [3950/6471], Loss: 1.9479, Perplexity: 7.0139
# Epoch [3/3], Step [4000/6471], Loss: 1.7699, Perplexity: 5.8702
# Epoch [3/3], Step [4050/6471], Loss: 2.0151, Perplexity: 7.5016
# Epoch [3/3], Step [4100/6471], Loss: 1.9283, Perplexity: 6.8778
# Epoch [3/3], Step [4150/6471], Loss: 1.8942, Perplexity: 6.6473
# Epoch [3/3], Step [4200/6471], Loss: 1.7160, Perplexity: 5.5622
# Epoch [3/3], Step [4250/6471], Loss: 1.7447, Perplexity: 5.7239
# Epoch [3/3], Step [4300/6471], Loss: 1.7552, Perplexity: 5.7844
# Epoch [3/3], Step [4350/6471], Loss: 1.8072, Perplexity: 6.0935
# Epoch [3/3], Step [4400/6471], Loss: 1.9163, Perplexity: 6.7958
# Epoch [3/3], Step [4450/6471], Loss: 1.9645, Perplexity: 7.1310
# Epoch [3/3], Step [4500/6471], Loss: 1.8362, Perplexity: 6.2727
# Epoch [3/3], Step [4550/6471], Loss: 2.0673, Perplexity: 7.9034
# Epoch [3/3], Step [4600/6471], Loss: 1.8767, Perplexity: 6.5322
# Epoch [3/3], Step [4650/6471], Loss: 1.7711, Perplexity: 5.8773
# Epoch [3/3], Step [4700/6471], Loss: 1.8946, Perplexity: 6.6501
# Epoch [3/3], Step [4750/6471], Loss: 1.9102, Perplexity: 6.7547
# Epoch [3/3], Step [4800/6471], Loss: 2.0141, Perplexity: 7.4937
# Epoch [3/3], Step [4850/6471], Loss: 1.8033, Perplexity: 6.0697
# Epoch [3/3], Step [4900/6471], Loss: 1.7552, Perplexity: 5.7847
# Epoch [3/3], Step [4950/6471], Loss: 2.0821, Perplexity: 8.0216
# Epoch [3/3], Step [5000/6471], Loss: 2.0776, Perplexity: 7.9850
# Epoch [3/3], Step [5050/6471], Loss: 1.7453, Perplexity: 5.7278
# Epoch [3/3], Step [5100/6471], Loss: 1.7108, Perplexity: 5.5332
# Epoch [3/3], Step [5150/6471], Loss: 1.6721, Perplexity: 5.3235
# Epoch [3/3], Step [5200/6471], Loss: 1.8568, Perplexity: 6.4030
# Epoch [3/3], Step [5250/6471], Loss: 1.9508, Perplexity: 7.0344
# Epoch [3/3], Step [5300/6471], Loss: 1.7686, Perplexity: 5.8624
# Epoch [3/3], Step [5350/6471], Loss: 1.8061, Perplexity: 6.0866
# Epoch [3/3], Step [5400/6471], Loss: 1.9824, Perplexity: 7.2599
# Epoch [3/3], Step [5450/6471], Loss: 1.7916, Perplexity: 5.9988
# Epoch [3/3], Step [5500/6471], Loss: 1.8196, Perplexity: 6.1693
# Epoch [3/3], Step [5550/6471], Loss: 1.8657, Perplexity: 6.4606
# Epoch [3/3], Step [5600/6471], Loss: 1.7323, Perplexity: 5.6536
# Epoch [3/3], Step [5650/6471], Loss: 1.8999, Perplexity: 6.6854
# Epoch [3/3], Step [5700/6471], Loss: 1.8808, Perplexity: 6.5585
# Epoch [3/3], Step [5750/6471], Loss: 1.6983, Perplexity: 5.4644
# Epoch [3/3], Step [5800/6471], Loss: 1.8492, Perplexity: 6.3545
# Epoch [3/3], Step [5850/6471], Loss: 2.0266, Perplexity: 7.5881
# Epoch [3/3], Step [5900/6471], Loss: 1.7450, Perplexity: 5.7257
# Epoch [3/3], Step [5950/6471], Loss: 1.8178, Perplexity: 6.1586
# Epoch [3/3], Step [6000/6471], Loss: 1.9499, Perplexity: 7.0279
# Epoch [3/3], Step [6050/6471], Loss: 1.9927, Perplexity: 7.3355
# Epoch [3/3], Step [6100/6471], Loss: 1.7192, Perplexity: 5.5799
# Epoch [3/3], Step [6150/6471], Loss: 2.1657, Perplexity: 8.7209
# Epoch [3/3], Step [6200/6471], Loss: 1.9140, Perplexity: 6.7804
# Epoch [3/3], Step [6250/6471], Loss: 1.7340, Perplexity: 5.6631
# Epoch [3/3], Step [6300/6471], Loss: 1.9401, Perplexity: 6.9591
# Epoch [3/3], Step [6350/6471], Loss: 2.1210, Perplexity: 8.3396
# Epoch [3/3], Step [6400/6471], Loss: 1.8551, Perplexity: 6.3926
# Epoch [3/3], Step [6450/6471], Loss: 1.9606, Perplexity: 7.1034

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
import data_loader_val
import os


# Build data loader.
val_loader = data_loader_val.get_loader(transform=transform_train,
                         mode='val',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder_val = EncoderCNN(embed_size)
encoder_val.eval()
decoder_val = DecoderRNN(embed_size, hidden_size, vocab_size)
decoder_val.eval()

encoder_file = 'encoder-3.pkl' 
decoder_file = 'decoder-3.pkl'

# !ls ./models/decoder-3.pkl

# Load the trained weights.
encoder_val.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
decoder_val.load_state_dict(torch.load(os.path.join('./models', decoder_file)))

# Move models to GPU if CUDA is available. 
encoder_val.to(device)
decoder_val.to(device)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# ./models/decoder-3.pkl
# DecoderRNN(
#   (embed): Embedding(8855, 512)
#   (lstm): LSTM(512, 512, batch_first=True)
#   (hidden2word): Linear(in_features=512, out_features=8855, bias=True)
# )

# %%
def clean_sentence(output):
    result = []
    for part in output[1:]:
        if part == 1:
            break
        result.append(data_loader.dataset.vocab.idx2word[part])
        
    return " ".join(result)

# %%
# [{"image_id": 391895, "caption": "Man riding a motor bike on a dirt road on the countryside."}]
captions = []
counter = 0
for img, ids in val_loader:
    # Move batch of images and captions to GPU if CUDA is available.
    images = img.to(device)  
    
    # Pass the inputs through the CNN-RNN model.
    features = encoder_val(images)
#    print(features.shape)
    for i in range(features.shape[0]):
        outputs = decoder_val.sample(features[i,:].unsqueeze(0).unsqueeze(1))
        #print(clean_sentence(outputs))
        captions.append({'image_id': ids[i].item(), 'caption' : clean_sentence(outputs)})
    counter += 1
    if counter % 10 == 0:
        print('.', end='')
# Out:
# ...............................................................

# %%
print(captions[0], len(captions))
# Out:
# {'image_id': 396496, 'caption': 'a black and white photo of a train .'} 40504

# %%
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO

annotation_file = '/opt/cocoapi/annotations/captions_val2014.json'

coco_caps = COCO(annotation_file)

def get_image_captions(image_id):
    annIds = coco_caps.getAnnIds(imgIds=image_id);
    anns = coco_caps.loadAnns(annIds)    
    return [item['caption'].split() for item in anns]
# Out:
# loading annotations into memory...
# Done (t=0.31s)
# creating index...
# index created!

# %%
import nltk

smoother = nltk.translate.bleu_score.SmoothingFunction()
total = 0.0
for item in captions:
    reference = get_image_captions(item['image_id'])
    hypothesis = item['caption'].split()
#    print(reference)
#    print(hypothesis)
    blue_score = nltk.translate.bleu_score.sentence_bleu(reference, hypothesis,smoothing_function=smoother.method4)
#    print(blue_score)
    total += blue_score
    
print("Averaged bleu {}".format(total / len(captions)))
# Out:
# Averaged bleu 0.29020426911550995

# %%
ref_corpus = []
hyp_corpus = []
for item in captions:
    ref_corpus.append(get_image_captions(item['image_id']))
    hyp_corpus.append(item['caption'].split())

#print(ref_corpus[0])
#print(hyp_corpus[0])
corpus_bleu = nltk.translate.bleu_score.corpus_bleu(ref_corpus, hyp_corpus, smoothing_function=smoother.method4)
print("corpus bleu {}".format(corpus_bleu))
# Out:
# corpus bleu 0.16474418122106105
